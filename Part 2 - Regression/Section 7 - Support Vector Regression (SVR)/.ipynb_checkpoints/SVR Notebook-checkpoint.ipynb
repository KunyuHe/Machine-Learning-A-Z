# %% [markdown]
# # SVR Notebook

# %% [markdown]
# #### *Author: Kunyu He*
# #### *University of Chicago, CAPP'20*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR

# %matplotlib notebook

# %% [markdown]
# ### Load Data

# %%
salary = pd.read_csv("Position_Salaries.csv")
salary.head()
# Out:
#             Position  Level  Salary
# 0   Business Analyst      1   45000
# 1  Junior Consultant      2   50000
# 2  Senior Consultant      3   60000
# 3            Manager      4   80000
# 4    Country Manager      5  110000

# %% [markdown]
# ### Data Cleaning

# %%
salary.isnull().sum()
# Out:
# Position    0
# Level       0
# Salary      0
# dtype: int64

# %% [markdown]
# No value missing.

# %% [markdown]
# ### Feature Selection

# %%
X = salary.iloc[:, 1:2].values
X.shape
# Out:
# (10, 1)

# %%
y = salary.Salary.values.reshape(-1, 1)
y.shape
# Out:
# (10, 1)

# %% [markdown]
# ### Feature Scaling

# %%
sc_X = StandardScaler()
sc_y = StandardScaler()

# %%
X_scaled = sc_X.fit_transform(X)
y_scaled = sc_y.fit_transform(y)
# Out:
# C:\Users\Administrator\Anaconda3\envs\kunyuhe\lib\site-packages\sklearn\utils\validation.py:590: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\Administrator\Anaconda3\envs\kunyuhe\lib\site-packages\sklearn\utils\validation.py:590: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\Administrator\Anaconda3\envs\kunyuhe\lib\site-packages\sklearn\utils\validation.py:590: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\Administrator\Anaconda3\envs\kunyuhe\lib\site-packages\sklearn\utils\validation.py:590: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %% [markdown]
# ### Model Training

# %% [markdown]
# As we only have ten observations, we are using the whole data set to train our model.

# %%
svr = SVR(kernel='rbf', gamma='auto')
SVR_raw = svr.fit(X, np.ravel(y))
SVR_sclaed = svr.fit(X_scaled, np.ravel(y_scaled))

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# #### Without Scaling

# %%
plt.scatter(X, y, color="red")
plt.plot(X, SVR_raw.predict(X), color="blue")

plt.title("Salary against Position Level (SVR without scaling)")
plt.xlabel("Position Level")
plt.ylabel("Salary ($)")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# #### Scaled

# %%
plt.scatter(X_scaled, y_scaled, color="red")
plt.plot(X_scaled, SVR_sclaed.predict(X_scaled), color="blue")

plt.title("Salary against Position Level (SVR sclaed)")
plt.xlabel("Position Level")
plt.ylabel("Salary ($)")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
