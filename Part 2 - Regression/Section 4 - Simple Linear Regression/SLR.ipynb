# %% [markdown]
# # SLR Notebook

# %% [markdown]
# #### *Author: Kunyu He*
# #### *University of Chicago, CAPP'20*

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %matplotlib notebook

# %% [markdown]
# ### Load Data

# %%
salary = pd.read_csv("Salary_Data.csv")
salary.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# Reshape both `X` and `y` into column vectors.

# %%
X = salary.YearsExperience.values.reshape(-1, 1)
y = salary.Salary.values.reshape(-1, 1)

# %% [markdown]
# ### Training and Test Set Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3,
                                                    random_state=123)

# %% [markdown]
# ### Model Training

# %%
slr = LinearRegression()
slr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# ### Model Prediction

# %%
train_pred = slr.predict(X_train)

# %%
plt.scatter(X_train, y_train, color="red")
plt.plot(X_train, train_pred, color="blue")

plt.title("Salary against Years of Experience (on training set)")
plt.xlabel("Years of experience")
plt.ylabel("Salary ($)")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Model Evaluation

# %%
test_pred = slr.predict(X_test)

# %%
plt.scatter(X_train, y_train, color="red")
plt.scatter(X_test, y_test, color="green")
plt.plot(X_train, train_pred, color="blue")

plt.title("Salary against Years of Experience (on both sets)")
plt.xlabel("Years of experience")
plt.ylabel("Salary ($)")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
