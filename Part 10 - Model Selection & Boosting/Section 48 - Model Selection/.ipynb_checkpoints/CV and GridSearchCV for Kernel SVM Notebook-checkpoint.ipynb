# %% [markdown]
# # Kernel SVM Notebook

# %% [markdown]
# #### *Author: Kunyu He*
# #### *University of Chicago, CAPP'20*

# %%
import matplotlib as mpl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from matplotlib.colors import ListedColormap
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
mpl.style.use("seaborn")

# %%
def actual_vs_predicted(ax, classifier, X, y, 
                        title=None, xlabel=None, ylabel=None,
                        postive_color="red", negative_color="green", edge_color="black",
                        postive_legend=None, negative_legend=None, legend_loc="best"):
    X1, X2 = np.meshgrid(np.arange(X[:, 0].min() - 1, X[:, 0].max() + 1, 0.01),
                         np.arange(X[:, 1].min() - 1, X[:, 1].max() + 1, 0.01))

    ax.contourf(X1, X2, classifier.predict(np.array([X1.ravel(),X2.ravel()]
                                                    ).T).reshape(X1.shape),
                 alpha = 0.75, cmap = ListedColormap((negative_color,
                                                      postive_color)))
    ax.scatter(X[y == 0, 0], X[y == 0, 1], c=negative_color,
               label=negative_legend, edgecolors=edge_color, alpha=0.8)
    ax.scatter(X[y == 1, 0], X[y == 1, 1], c=postive_color,
               label=postive_legend, edgecolors=edge_color, alpha=0.8)
    
    ax.set_xlim(X1.min(), X1.max())
    ax.set_ylim(X2.min(), X2.max())
    ax.set_title(title, fontdict={'fontsize': 15, 'fontweight': "bold"})
    ax.set_xlabel(xlabel, fontsize=13)
    ax.set_ylabel(ylabel, fontsize=13)
    ax.legend(frameon=True, framealpha=0.3, fancybox=True, fontsize=12)

# %% [markdown]
# ### Load Data

# %%
network = pd.read_csv("Social_Network_Ads.csv")
network.head()
# Out:
#     User ID  Gender   Age  EstimatedSalary  Purchased
# 0  15624510    Male  19.0          19000.0          0
# 1  15810944    Male  35.0          20000.0          0
# 2  15668575  Female  26.0          43000.0          0
# 3  15603246  Female  27.0          57000.0          0
# 4  15804002    Male  19.0          76000.0          0

# %% [markdown]
# ### Data Cleaning

# %%
network.shape
# Out:
# (400, 5)

# %%
network.isnull().sum(axis=0)
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %% [markdown]
# No missing data.

# %% [markdown]
# ### Feature Selection

# %%
X = network.iloc[:, 2:4].values.astype(float)
X.shape
# Out:
# (400, 2)

# %%
y = network.Purchased.values.astype(float)
y.shape
# Out:
# (400,)

# %% [markdown]
# ### Training and Test Set Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25,
                                                    random_state=123)

# %% [markdown]
# ### Feature Scaling

# %%
sc_X = StandardScaler()

X_train = sc_X.fit_transform(X_train)
X_test = sc_X.fit_transform(X_test)

# %% [markdown]
# ### Model Training

# %% [markdown]
# #### Linear Kernel

# %%
svmc_linear = SVC(kernel="linear", random_state=123)
svmc_linear.fit(X_train, y_train)
linear_pred = svmc_linear.predict(X_test)

# %%
confusion_matrix(y_test, linear_pred)
# Out:
# array([[59,  4],
#        [14, 23]], dtype=int64)

# %%
fig = plt.figure(figsize=[24, 8])
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

actual_vs_predicted(ax1, svmc_linear, X_train, y_train,
                    title="SVM Linear Classifier: the classified training set",
                    xlabel="Age", ylabel="Estimated Salary",
                    postive_legend="Bought SUV", negative_legend="Did not buy SUV")

actual_vs_predicted(ax2, svmc_linear, X_test, y_test,
                    title="SVM Linear Classifier: the classified test set",
                    xlabel="Age", ylabel="Estimated Salary",
                    postive_legend="Bought SUV", negative_legend="Did not buy SUV")

plt.show()

# %% [markdown]
# #### Gaussian (RBF) Kernel

# %%
svmc_rbf = SVC(kernel="rbf", random_state=123)
svmc_rbf.fit(X_train, y_train)
rbf_pred = svmc_rbf.predict(X_test)

# %%
confusion_matrix(y_test, rbf_pred)
# Out:
# array([[55,  8],
#        [ 3, 34]], dtype=int64)

# %%
fig = plt.figure(figsize=[24, 8])
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

actual_vs_predicted(ax1, svmc_rbf, X_train, y_train,
                    title="SVM RBF Classifier: the classified training set",
                    xlabel="Age", ylabel="Estimated Salary",
                    postive_legend="Bought SUV", negative_legend="Did not buy SUV")

actual_vs_predicted(ax2, svmc_rbf, X_test, y_test,
                    title="SVM RBF Classifier: the classified test set",
                    xlabel="Age", ylabel="Estimated Salary",
                    postive_legend="Bought SUV", negative_legend="Did not buy SUV")

plt.show()

# %% [markdown]
# #### Polynomial Kernel

# %%
svmc_poly = SVC(kernel="poly", degree=3, random_state=123)
svmc_poly.fit(X_train, y_train)
poly_pred = svmc_poly.predict(X_test)

# %%
confusion_matrix(y_test, poly_pred)
# Out:
# array([[61,  2],
#        [15, 22]], dtype=int64)

# %%
fig = plt.figure(figsize=[24, 8])
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

actual_vs_predicted(ax1, svmc_poly, X_train, y_train,
                    title="SVM Polynomial (degree=3) Classifier: the classified training set",
                    xlabel="Age", ylabel="Estimated Salary",
                    postive_legend="Bought SUV", negative_legend="Did not buy SUV")

actual_vs_predicted(ax2, svmc_poly, X_test, y_test,
                    title="SVM Polynomial (degree=3) Classifier: the classified test set",
                    xlabel="Age", ylabel="Estimated Salary",
                    postive_legend="Bought SUV", negative_legend="Did not buy SUV")

plt.show()

# %% [markdown]
# #### Sigmoid Kernel

# %%
svmc_sig = SVC(kernel="sigmoid", random_state=123)
svmc_sig.fit(X_train, y_train)
sig_pred = svmc_sig.predict(X_test)

# %%
confusion_matrix(y_test, sig_pred)
# Out:
# array([[53, 10],
#        [17, 20]], dtype=int64)

# %%
fig = plt.figure(figsize=[24, 8])
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

actual_vs_predicted(ax1, svmc_sig, X_train, y_train,
                    title="SVM Sigmoid Classifier: the classified training set",
                    xlabel="Age", ylabel="Estimated Salary",
                    postive_legend="Bought SUV", negative_legend="Did not buy SUV")

actual_vs_predicted(ax2, svmc_sig, X_test, y_test,
                    title="SVM Sigmoid Classifier: the classified test set",
                    xlabel="Age", ylabel="Estimated Salary",
                    postive_legend="Bought SUV", negative_legend="Did not buy SUV")

plt.show()

# %% [markdown]
# ### CV for Model Evaluation

# %% [markdown]
# #### Linear Kernel

# %%
svmc_linear_accuracies = cross_val_score(svmc_linear, X_train, y_train, cv=10,
                                         n_jobs=-1)
print("CV accuracy is {}, with a standard deviation of {}.".format(round(svmc_linear_accuracies.mean(), 4),
                                                                   round(svmc_linear_accuracies.std(), 4)))
# Out:
# CV accuracy is 0.8408, with a standard deviation of 0.0553.

# %% [markdown]
# #### Gaussian (RBF) Kernel

# %%
svmc_rbf_accuracies = cross_val_score(svmc_rbf, X_train, y_train, cv=10,
                                      n_jobs=-1)
print("CV accuracy is {}, with a standard deviation of {}.".format(round(svmc_rbf_accuracies.mean(), 4),
                                                                   round(svmc_rbf_accuracies.std(), 4)))
# Out:
# CV accuracy is 0.9265, with a standard deviation of 0.0326.

# %% [markdown]
# #### Polynomial Kernel

# %%
svmc_poly_accuracies = cross_val_score(svmc_poly, X_train, y_train, cv=10,
                                       n_jobs=-1)
print("CV accuracy is {}, with a standard deviation of {}.".format(round(svmc_poly_accuracies.mean(), 4),
                                                                   round(svmc_poly_accuracies.std(), 4)))
# Out:
# CV accuracy is 0.8566, with a standard deviation of 0.05.

# %% [markdown]
# #### Sigmoid Kernel

# %%
svmc_sig_accuracies = cross_val_score(svmc_sig, X_train, y_train, cv=10,
                                    n_jobs=-1)
print("CV accuracy is {}, with a standard deviation of {}.".format(round(svmc_sig_accuracies.mean(), 4),
                                                                   round(svmc_sig_accuracies.std(), 4)))
# Out:
# CV accuracy is 0.6593, with a standard deviation of 0.0797.

# %% [markdown]
# ### Further Model Training - Hyperparameter Tuning

# %%
parameters = {"kernel": ["linear", "rbf", "poly", "sigmoid"],
              "C": [1, 2, 4, 8, 16],
              "gamma": [0.5, 0.1, 0.01, 0.001],
              "decision_function_shape": ["ovo", "ovr"],
              "degree": [2, 3, 4, 5]}

# %%
grid = GridSearchCV(SVC(random_state=123), param_grid=parameters,
                    scoring=["roc_auc", "accuracy"], n_jobs=-1, cv=10,
                    iid=True, refit="accuracy")
grid.fit(X_train, y_train)
print("The best set of hyperparameters to use: \n", grid.best_params_)
print("which has a CV accuracy of ", round(grid.best_score_, 4))
# Out:
# The best set of hyperparameters to use:
#  {'C': 1, 'decision_function_shape': 'ovo', 'degree': 2, 'gamma': 0.5, 'kernel': 'rbf'}
# which has a CV accuracy of  0.9267

# %%
svmc_best = SVC(**grid.best_params_, random_state=123)
svmc_best.fit(X_train, y_train)
best_pred = svmc_best.predict(X_test)

# %%
confusion_matrix(y_test, best_pred)
# Out:
# array([[55,  8],
#        [ 3, 34]], dtype=int64)

# %% [markdown]
# The test accuracy is 0.89, which is only slightly lower than the CV accuracy, indicating no severe over-fitting.

# %%
fig = plt.figure(figsize=[24, 8])
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

actual_vs_predicted(ax1, svmc_best, X_train, y_train,
                    title="SVM Best Classifier: the classified training set",
                    xlabel="Age", ylabel="Estimated Salary",
                    postive_legend="Bought SUV", negative_legend="Did not buy SUV")

actual_vs_predicted(ax2, svmc_best, X_test, y_test,
                    title="SVM Best Classifier: the classified test set",
                    xlabel="Age", ylabel="Estimated Salary",
                    postive_legend="Bought SUV", negative_legend="Did not buy SUV")

plt.show()
